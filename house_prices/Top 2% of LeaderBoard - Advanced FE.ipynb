# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')
from scipy.stats import norm, skew
import numpy as np
import seaborn as sns

# %% [markdown]
# # Assignment 1 - House Price Prediction

# %% [markdown]
# The workbook is structured as followed:
#
# 1.0 ) Data Cleaning and Pre-processing
#
# * Outliers
# * Statistical transformations
#
# 2.0 Feature Engineering
#
# * Concatenation
# * NA's
# * Incorrect values
# * Factorization
# * Further Statistical transformation
# * Column removal
# * Creating features
# * Dummies
# * In-depth outlier detection
# * Overfit prevention
# * Baseline model
#
# 3.0) Feature Selection
#
# * Filter methods
# * baseline coefficients
# * Embedded methods
# * L2: Ridge Regression
# * L1: Lasso regression
# * In-depth coefficient analysis
# * Elasticnet
# * XGBoost
# * SVR
# * LightGBM
#
# 4.0) Ensemble methods
#
# * Stacked generalizations
# * Averaging
# * standard
# * weighted

# %% [markdown]
# # 1.0 Read Data

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
print('Train set size : ', train.shape)
print('Test set size : ', test.shape)
# Out:
# Train set size :  (1460, 81)
# Test set size :  (1459, 80)

# %% [markdown]
# # 2.0 Data Cleaning and Pre-processing

# %% [markdown]
# # 2.1 Outliers
# According to the documentation of the dataset (http://ww2.amstat.org/publications/jse/v19n3/Decock/DataDocumentation.txt) there are outliers present that are recommended to be removed. Let's plot SalePrice vs GR LIV AREA to view these.

# %%
plt.figure(figsize=(10,7))
plt.scatter(train.GrLivArea, train.SalePrice)

# %% [markdown]
# These outliers are extremely clear. The documentation recommends removing all houses above 4000 sq ft living area. Trial and error showed that this led to a little bit underfitting. Better performance was above 4500 sq.

# %%
train = train[train.GrLivArea < 4500]
plt.figure(figsize=(10,7))
plt.scatter(train.GrLivArea, train.SalePrice)

# %%
train.drop(['Id'], axis=1,inplace=True)
test.drop(['Id'], axis=1,inplace=True)

# %%
print('Train set size : ', train.shape)
print('Test set size : ', test.shape)
# Out:
# Train set size :  (1458, 80)
# Test set size :  (1459, 79)

# %% [markdown]
# # 2.2 Statistical transformation
#
# Let's have a look at how the target variable is distributed.

# %%
df = pd.concat([train.SalePrice, np.log(train.SalePrice + 1).rename('LogSalePrice')], axis=1,
              names=['SalePrice', 'LogSalePrice'])
df.head()
# Out:
#    SalePrice  LogSalePrice
# 0     208500     12.247699
# 1     181500     12.109016
# 2     223500     12.317171
# 3     140000     11.849405
# 4     250000     12.429220

# %%
plt.figure(figsize=(10,6))
plt.subplot(1, 2, 1)
sns.distplot(train.SalePrice, kde=False, fit = norm)
plt.subplot(1, 2, 2)
sns.distplot(np.log(train.SalePrice + 1), kde=False, fit = norm)
plt.xlabel('Log SalePrice')
# Out:
# C:\Users\Martin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,0,'Log SalePrice')

# %% [markdown]
# There seems to be clear evidence of right-skewedness in the target variable. We can correct this with a simple log transformation.

# %%
train.SalePrice = np.log1p(train.SalePrice)

# %% [markdown]
# # 3.0 Feature Engineering

# %% [markdown]
# # 3.1 Concatenation
# To keep consistency between test and train features we concatenate the two sets while remembering the index so we can split it later again.

# %%
y = train.SalePrice.reset_index(drop=True)
train_features = train.drop(['SalePrice'], axis=1)
test_features = test

# %%
print(train_features.shape)
print(test_features.shape)
# Out:
# (1458, 79)
# (1459, 79)

# %%
features = pd.concat([train_features, test_features]).reset_index(drop=True)
features.shape
# Out:
# (2917, 79)

# %% [markdown]
# # 3.2 NA's
# Let's figure out what NA's excist, sort them by categories and impute them in the best possible way.

# %%
nulls = features.isnull().sum()
nullcols = nulls.loc[(nulls != 0)]
dtypes = features.dtypes
dtypes2 = dtypes.loc[(nulls) != 0]
info = pd.concat([nullcols, dtypes2], axis=1).sort_values(by=0, ascending=False)
print(info)
print('There are', len(nullcols), 'columns with missing values')
# Out:
#                  0        1
# PoolQC        2908   object
# MiscFeature   2812   object
# Alley         2719   object
# Fence         2346   object
# FireplaceQu   1420   object
# LotFrontage    486  float64
# GarageFinish   159   object
# GarageQual     159   object
# GarageCond     159   object
# GarageYrBlt    159  float64
# GarageType     157   object
# BsmtExposure    82   object
# BsmtCond        82   object
# BsmtQual        81   object
# BsmtFinType2    80   object
# BsmtFinType1    79   object
# MasVnrType      24   object
# MasVnrArea      23  float64
# MSZoning         4   object
# BsmtFullBath     2  float64
# BsmtHalfBath     2  float64
# Functional       2   object
# Utilities        2   object
# GarageArea       1  float64
# GarageCars       1  float64
# Electrical       1   object
# KitchenQual      1   object
# TotalBsmtSF      1  float64
# BsmtUnfSF        1  float64
# BsmtFinSF2       1  float64
# BsmtFinSF1       1  float64
# Exterior2nd      1   object
# Exterior1st      1   object
# SaleType         1   object
# There are 34 columns with missing values

# %% [markdown]
# Most of these can be filled with 'None'. Some exceptions though:
#
# * Functional: The documentation says that we should assume "Typ", so lets impute that.
# * Electrical: The documentation doesn't give any information but obviously every house has this so let's impute the most common value: "SBrkr".
# * KitchenQual: Similar to Electrical, most common value: "TA".
# * Exterior 1 and Exterior 2: Let's use the most common one here.
# * SaleType: Similar to electrical, let's use most common value.

# %%
features['Functional'] = features['Functional'].fillna('Typ')
features['Electrical'] = features['Electrical'].fillna('SBrkr')
features['KitchenQual'] = features['KitchenQual'].fillna('TA')
features['Exterior1st'] = features['Exterior1st'].fillna(features['Exterior1st'].mode()[0])
features['Exterior2nd'] = features['Exterior2nd'].fillna(features['Exterior2nd'].mode()[0])
features['SaleType'] = features['SaleType'].fillna(features['SaleType'].mode()[0])

# %% [markdown]
# Let's check some points individually to figure out the best imputation strategy

# %%
pd.set_option('max_columns', None)
features[features['PoolArea']>0 & features['PoolQC'].isnull()]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197           75       RL        174.0    25419   Pave   NaN      Reg
# 809           20       RL         78.0    10140   Pave   NaN      Reg
# 1169          80       RL         76.0     9880   Pave   NaN      Reg
# 1181          60       RL        160.0    15623   Pave   NaN      IR1
# 1384          60       RL         80.0    16692   Pave   NaN      IR1
# 1421          80       RL          NaN    19690   Pave   NaN      IR1
# 1972          20       RL        106.0    12720   Pave   NaN      Reg
# 2418          20       RL         75.0     9532   Pave   NaN      Reg
# 2501          50       RL        104.0    23920   Pave   NaN      Reg
# 2571          20       RL         70.0    18044   Pave   NaN      IR1
# 2597          20       RL        200.0    43500   Pave   NaN      Reg
# 2708          80       RL        100.0    14330   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 197          Lvl    AllPub    Corner       Gtl        NAmes     Artery
# 809          Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1169         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1181         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 1384         Lvl    AllPub    Inside       Gtl       NWAmes       RRAn
# 1421         Lvl    AllPub   CulDSac       Gtl      Edwards       Norm
# 1972         HLS    AllPub    Inside       Mod      NridgHt       Norm
# 2418         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 2501         Lvl    AllPub    Inside       Gtl      SawyerW      Feedr
# 2571         HLS    AllPub   CulDSac       Gtl      Crawfor       Norm
# 2597         Lvl    AllPub    Inside       Gtl      Mitchel     Artery
# 2708         Low    AllPub    Corner       Gtl      Veenker       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 197        Norm     1Fam     2Story            8            4       1918
# 809        Norm     1Fam     1Story            6            6       1974
# 1169       Norm     1Fam       SLvl            6            6       1977
# 1181       Norm     1Fam     2Story           10            5       1996
# 1384       Norm     1Fam     2Story            7            5       1978
# 1421       Norm     1Fam       SLvl            6            7       1966
# 1972       Norm     1Fam     1Story           10            5       2003
# 2418       Norm     1Fam     1Story            4            6       1953
# 2501       Norm     1Fam     1.5Fin            6            5       1984
# 2571       Norm     1Fam     1Story            8            5       1986
# 2597       Norm     1Fam     1Story            3            5       1953
# 2708       Norm     1Fam       SLvl            7            4       1974
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 197           1990     Gable  CompShg      Stucco      Stucco       None
# 809           1999       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1169          1977     Gable  CompShg     Plywood     Plywood       None
# 1181          1996       Hip  CompShg     Wd Sdng     ImStucc       None
# 1384          1978     Gable  CompShg     Plywood     Plywood    BrkFace
# 1421          1966      Flat  Tar&Grv     Plywood     Plywood       None
# 1972          2003       Hip  CompShg     MetalSd     MetalSd      Stone
# 2418          1953     Gable  CompShg     VinylSd     VinylSd       None
# 2501          1984     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 2571          1986     Gable  CompShg     WdShing     Plywood       None
# 2597          1953     Gable  CompShg     MetalSd     MetalSd       None
# 2708          1974     Gable  CompShg     WdShing     Wd Sdng    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 197          0.0        Gd        Gd      PConc       TA       TA
# 809         99.0        TA        TA     CBlock       TA       TA
# 1169         0.0        TA        TA     CBlock       TA       TA
# 1181         0.0        Gd        TA      PConc       Ex       TA
# 1384       184.0        TA        TA     CBlock       Gd       TA
# 1421         0.0        Gd        Gd     CBlock       Gd       TA
# 1972       680.0        Ex        TA      PConc       Ex       TA
# 2418         0.0        TA        TA     CBlock       TA       TA
# 2501         0.0        TA        TA     CBlock       TA       TA
# 2571         0.0        Gd        TA     CBlock       Gd       TA
# 2597         0.0        TA        TA     CBlock      NaN      NaN
# 2708       145.0        Gd        Fa     CBlock       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 197            No          GLQ      1036.0          LwQ       184.0
# 809            No          ALQ       663.0          LwQ       377.0
# 1169           Av          ALQ       522.0          Unf         0.0
# 1181           Av          GLQ      2096.0          Unf         0.0
# 1384           No          BLQ       790.0          LwQ       469.0
# 1421           Av          Unf         0.0          Unf         0.0
# 1972           Gd          GLQ      2257.0          Unf         0.0
# 2418           No          BLQ       595.0          Rec       354.0
# 2501           No          Unf         0.0          Unf         0.0
# 2571           No          Unf         0.0          Unf         0.0
# 2597          NaN          NaN         0.0          NaN         0.0
# 2708           Gd          ALQ      1023.0          BLQ       497.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 197       140.0       1360.0    GasA        Gd          Y      SBrkr
# 809         0.0       1040.0    GasA        Fa          Y      SBrkr
# 1169      574.0       1096.0    GasA        TA          Y      SBrkr
# 1181      300.0       2396.0    GasA        Ex          Y      SBrkr
# 1384      133.0       1392.0    GasA        TA          Y      SBrkr
# 1421      697.0        697.0    GasA        TA          Y      SBrkr
# 1972      278.0       2535.0    GasA        Ex          Y      SBrkr
# 2418      156.0       1105.0    GasA        Gd          Y      SBrkr
# 2501     1105.0       1105.0    GasA        Ex          Y      SBrkr
# 2571      279.0        279.0    GasA        Gd          Y      SBrkr
# 2597        0.0          0.0    GasA        Ex          Y      SBrkr
# 2708      228.0       1748.0    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 197       1360      1360           392       3112           1.0           1.0
# 809       1309         0             0       1309           1.0           0.0
# 1169      1118         0             0       1118           1.0           0.0
# 1181      2411      2065             0       4476           1.0           0.0
# 1384      1392      1392             0       2784           1.0           0.0
# 1421      1575       626             0       2201           0.0           0.0
# 1972      2470         0             0       2470           2.0           0.0
# 2418      1647         0             0       1647           1.0           0.0
# 2501      1105       717             0       1822           0.0           0.0
# 2571      2726         0             0       2726           0.0           0.0
# 2597      2034         0             0       2034           0.0           0.0
# 2708      2151       495             0       2646           1.0           2.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 197          2         0             4             1          Gd
# 809          1         1             3             1          Gd
# 1169         1         0             3             1          TA
# 1181         3         1             4             1          Ex
# 1384         3         1             5             1          Gd
# 1421         2         0             4             1          Gd
# 1972         1         1             1             1          Ex
# 2418         1         0             3             1          TA
# 2501         2         0             4             1          Gd
# 2571         2         1             2             1          Gd
# 2597         1         0             2             1          TA
# 2708         2         0             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 197              8        Typ           1          Ex     Detchd       1918.0
# 809              5        Typ           1          Fa     Attchd       1974.0
# 1169             6        Typ           1          Po     Attchd       1977.0
# 1181            10        Typ           2          TA     Attchd       1996.0
# 1384            12        Typ           2          TA     Attchd       1978.0
# 1421             8        Typ           1          Gd     Attchd       1966.0
# 1972             7        Typ           2          Gd     Attchd       2003.0
# 2418             6       Min1           1          Fa     Attchd       1953.0
# 2501             7       Min2           1          Po     Attchd       1984.0
# 2571             6        Typ           1          Gd     Attchd       1986.0
# 2597             9       Min1           0         NaN     2Types       1953.0
# 2708             9        Mod           4          TA     Attchd       1974.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 197           Unf         2.0       795.0         TA         TA          Y
# 809           RFn         2.0       484.0         TA         TA          Y
# 1169          Fin         1.0       358.0         TA         TA          Y
# 1181          Fin         3.0       813.0         TA         TA          Y
# 1384          RFn         2.0       564.0         TA         TA          Y
# 1421          Unf         2.0       432.0         Gd         Gd          Y
# 1972          Fin         3.0       789.0         TA         TA          Y
# 2418          Fin         1.0       280.0         TA         TA          Y
# 2501          Unf         2.0       515.0         TA         TA          P
# 2571          Fin         2.0       691.0         Gd         Gd          Y
# 2597          RFn         4.0      1041.0         TA         TA          N
# 2708          RFn         2.0       550.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 197            0           16            552          0            0
# 809          265            0              0          0            0
# 1169         203            0              0          0            0
# 1181         171           78              0          0            0
# 1384           0          112              0          0          440
# 1421         586          236              0          0            0
# 1972         154           65              0          0          216
# 2418         225            0              0          0            0
# 2501           0          195           1012          0            0
# 2571         216           64            169          0            0
# 2597         483          266              0          0            0
# 2708         641          100              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 197        512     Ex  GdPrv         NaN        0       3    2006       WD
# 809        648     Fa  GdPrv         NaN        0       1    2006       WD
# 1169       576     Gd  GdPrv         NaN        0       7    2008       WD
# 1181       555     Ex  MnPrv         NaN        0       7    2007       WD
# 1384       519     Fa  MnPrv        TenC     2000       7    2006       WD
# 1421       738     Gd  GdPrv         NaN        0       8    2006       WD
# 1972       144     Ex    NaN         NaN        0       2    2008       WD
# 2418       368    NaN  GdPrv         NaN        0       2    2007       WD
# 2501       444    NaN    NaN         NaN        0       4    2007       WD
# 2571       228     Ex    NaN         NaN        0       8    2007       WD
# 2597       561    NaN  GdPrv         NaN        0       6    2007       WD
# 2708       800     Gd  GdPrv         NaN        0       1    2006       WD
#
#      SaleCondition
# 197        Abnorml
# 809         Normal
# 1169        Normal
# 1181       Abnorml
# 1384        Normal
# 1421        Alloca
# 1972        Normal
# 2418        Normal
# 2501        Normal
# 2571        Normal
# 2597        Normal
# 2708        Normal

# %% [markdown]
# There are three NaN's foor PoolQC that have a PoolArea. Let's impute them based on overall quality of the house.

# %%
features.groupby(['PoolQC'])['PoolArea'].mean()
# Out:
# PoolQC
# Ex    359.750000
# Fa    583.500000
# Gd    704.666667
# Name: PoolArea, dtype: float64

# %%
features.loc[2418, 'PoolQC'] = 'Ex'
features.loc[2501, 'PoolQC'] = 'Ex'
features.loc[2597, 'PoolQC'] = 'Fa'

# %%
features[(features['GarageType']=='Detchd') & (features['GarageYrBlt'].isnull())]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2124          60       RM         57.0     8094   Pave  Grvl      Reg
# 2574          70       RM         50.0     9060   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 2124         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 2574         Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 2124       Norm   2fmCon     2.5Unf            6            8       1910
# 2574       Norm     1Fam     2Story            5            6       1923
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 2124          1983     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 2574          1999     Gable  CompShg     Wd Sdng     Plywood       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 2124         0.0        TA        TA      PConc       TA       TA
# 2574         0.0        TA        TA     BrkTil       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 2124           Mn          Rec       196.0          Unf         0.0
# 2574           No          ALQ       548.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 2124     1046.0       1242.0    GasA        Gd          Y      SBrkr
# 2574      311.0        859.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 2124      1242       742             0       1984           0.0           0.0
# 2574       942       886             0       1828           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 2124         2         0             5             1          TA
# 2574         2         0             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 2124             8        Typ           0         NaN     Detchd          NaN
# 2574             6        Typ           0         NaN     Detchd          NaN
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 2124          NaN         1.0       360.0        NaN        NaN          Y
# 2574          NaN         NaN         NaN        NaN        NaN          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 2124          64            0            180          0            0
# 2574         174            0            212          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 2124         0    NaN  MnPrv        Shed     1000       9    2008       WD
# 2574         0    NaN  MnPrv         NaN        0       3    2007       WD
#
#      SaleCondition
# 2124        Normal
# 2574        Alloca

# %% [markdown]
# So there are houses with garages that are detached but that have NaN's for all other Garage variables. Let's impute these manually too.

# %%
features.loc[2124, 'GarageYrBlt'] = features['GarageYrBlt'].median()
features.loc[2574, 'GarageYrBlt'] = features['GarageYrBlt'].median()

features.loc[2124, 'GarageFinish'] = features['GarageFinish'].mode()[0]
features.loc[2574, 'GarageFinish'] = features['GarageFinish'].mode()[0]

features.loc[2574, 'GarageCars'] = features['GarageCars'].median()

features.loc[2574, 'GarageArea'] = features['GarageArea'].median()

features.loc[2124, 'GarageQual'] = features['GarageQual'].mode()[0]
features.loc[2574, 'GarageQual'] = features['GarageQual'].mode()[0]

features.loc[2124, 'GarageCond'] = features['GarageCond'].mode()[0]
features.loc[2574, 'GarageCond'] = features['GarageCond'].mode()[0]

# %% [markdown]
# Let's look at the basements:

# %%
basement_columns = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
                   'BsmtFinType2', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
                   'TotalBsmtSF']
tempdf = features[basement_columns]
tempdfnulls = tempdf[tempdf.isnull().any(axis=1)]

# %%
# now just select the rows that have less then 5 NA's, meaning there is incongruency in the row.
tempdfnulls[(tempdfnulls.isnull()).sum(axis=1) < 5]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  BsmtFinSF1  \
# 332        Gd       TA           No          GLQ          NaN      1124.0
# 947        Gd       TA          NaN          Unf          Unf         0.0
# 1485       Gd       TA          NaN          Unf          Unf         0.0
# 2038       Gd      NaN           Mn          GLQ          Rec      1044.0
# 2183       TA      NaN           No          BLQ          Unf      1033.0
# 2215      NaN       Fa           No          Unf          Unf         0.0
# 2216      NaN       TA           No          Unf          Unf         0.0
# 2346       Gd       TA          NaN          Unf          Unf         0.0
# 2522       TA      NaN           Av          ALQ          Unf       755.0
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 332        479.0     1603.0       3206.0
# 947          0.0      936.0        936.0
# 1485         0.0     1595.0       1595.0
# 2038       382.0        0.0       1426.0
# 2183         0.0       94.0       1127.0
# 2215         0.0      173.0        173.0
# 2216         0.0      356.0        356.0
# 2346         0.0      725.0        725.0
# 2522         0.0      240.0        995.0

# %% [markdown]
# Let's impute all incongruencies with the most likely value.

# %%
features.loc[332, 'BsmtFinType2'] = 'ALQ' #since smaller than SF1
features.loc[947, 'BsmtExposure'] = 'No' 
features.loc[1485, 'BsmtExposure'] = 'No'
features.loc[2038, 'BsmtCond'] = 'TA'
features.loc[2183, 'BsmtCond'] = 'TA'
features.loc[2215, 'BsmtQual'] = 'Po' #v small basement so let's do Poor.
features.loc[2216, 'BsmtQual'] = 'Fa' #similar but a bit bigger.
features.loc[2346, 'BsmtExposure'] = 'No' #unfinished bsmt so prob not.
features.loc[2522, 'BsmtCond'] = 'Gd' #cause ALQ for bsmtfintype1

# %% [markdown]
# Zoning is also interesting

# %%
subclass_group = features.groupby('MSSubClass')
zoning_modes = subclass_group['MSZoning'].apply(lambda x: x.mode()[0])
zoning_modes
# Out:
# MSSubClass
# 20     RL
# 30     RM
# 40     RL
# 45     RM
# 50     RL
# 60     RL
# 70     RM
# 75     RM
# 80     RL
# 85     RL
# 90     RL
# 120    RL
# 150    RL
# 160    RM
# 180    RM
# 190    RL
# Name: MSZoning, dtype: object

# %%
features['MSZoning'] = features.groupby('MSSubClass')['MSZoning'].transform(lambda x: x.fillna(x.mode()[0]))

# %% [markdown]
# For the rest we will just use a loop to impute 'None' value.

# %%
objects = []
for i in features.columns:
    if features[i].dtype == object:
        objects.append(i)
        
features.update(features[objects].fillna('None'))

nulls = np.sum(features.isnull())
nullcols = nulls.loc[(nulls != 0)]
dtypes = features.dtypes
dtypes2 = dtypes.loc[(nulls != 0)]
info = pd.concat([nullcols, dtypes2], axis=1).sort_values(by=0, ascending=False)
print(info)
print("There are", len(nullcols), "columns with missing values")
# Out:
#                 0        1
# LotFrontage   486  float64
# GarageYrBlt   157  float64
# MasVnrArea     23  float64
# BsmtFullBath    2  float64
# BsmtHalfBath    2  float64
# BsmtFinSF1      1  float64
# BsmtFinSF2      1  float64
# BsmtUnfSF       1  float64
# TotalBsmtSF     1  float64
# There are 9 columns with missing values

# %% [markdown]
# Now let's think about imputing the missing values in the numerical features. Most of the time I will impute 0, but sometimes something else is needed.
#
# * LotFrontage: This is linear feet of street connected to property. Let's impute with the median per neighborhood since I assume this is extremely linked to what kind of area you live in.

# %%
neighborhood_group = features.groupby('Neighborhood')
lot_median = neighborhood_group['LotFrontage'].median()
lot_median
# Out:
# Neighborhood
# Blmngtn    43.0
# Blueste    24.0
# BrDale     21.0
# BrkSide    51.0
# ClearCr    80.5
# CollgCr    70.0
# Crawfor    70.0
# Edwards    64.5
# Gilbert    64.0
# IDOTRR     60.0
# MeadowV    21.0
# Mitchel    74.0
# NAmes      73.0
# NPkVill    24.0
# NWAmes     80.0
# NoRidge    89.0
# NridgHt    92.0
# OldTown    60.0
# SWISU      60.0
# Sawyer     72.0
# SawyerW    67.0
# Somerst    72.5
# StoneBr    60.0
# Timber     82.0
# Veenker    80.0
# Name: LotFrontage, dtype: float64

# %%
features['LotFrontage'] = features.groupby('Neighborhood')['LotFrontage'].transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# Let's also take a close look at GarageYrBlt

# %%
features[(features['GarageYrBlt'].isnull()) & (features['GarageArea'] > 0)]
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %% [markdown]
# GarageYrBlt does not have any incongruencies. Let's also examine MasVnrArea.

# %%
features[(features['MasVnrArea'].isnull())]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 234           60       RL         64.0     7851   Pave  None      Reg
# 528           20       RL         70.0    32668   Pave  None      IR1
# 649           60       FV         65.0     8125   Pave  None      Reg
# 935           20       RL         67.0    10083   Pave  None      Reg
# 972           20       FV         95.0    11639   Pave  None      Reg
# 976          120       FV         35.0     4274   Pave  Pave      IR1
# 1242          20       RL        107.0    13891   Pave  None      Reg
# 1277          60       RL         75.0     9473   Pave  None      Reg
# 1689          60       RL         64.0    12891   Pave  None      IR1
# 1704          20       FV         90.0     7993   Pave  None      IR1
# 1880          60       RL         70.0     8749   Pave  None      Reg
# 1990          60       RL         64.0     7750   Pave  None      Reg
# 2002          20       RL         87.0    10037   Pave  None      Reg
# 2039          60       FV         72.5     7500   Pave  None      Reg
# 2309          60       RL         59.0    15810   Pave  None      IR1
# 2323          80       RL         64.0    11950   Pave  None      IR1
# 2338          20       RL         85.0     9965   Pave  None      Reg
# 2347          60       FV        112.0    12217   Pave  None      IR1
# 2366         120       FV         30.0     5330   Pave  Pave      IR2
# 2590          20       RL         68.0     8298   Pave  None      IR1
# 2655          60       RL        103.0    12867   Pave  None      IR1
# 2684          20       RL         49.0    15218   Pave  None      IR1
# 2860          20       RL         75.0     8050   Pave  None      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 234          Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 528          Lvl    AllPub   CulDSac       Gtl      Crawfor       Norm
# 649          Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 935          Lvl    AllPub    Inside       Gtl      SawyerW       Norm
# 972          Lvl    AllPub    Corner       Gtl      Somerst       Norm
# 976          Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 1242         Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 1277         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1689         Lvl    AllPub    Corner       Gtl      Gilbert       Norm
# 1704         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 1880         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1990         Lvl    AllPub    Inside       Gtl      Gilbert       RRAn
# 2002         Lvl    AllPub    Corner       Gtl      Somerst      Feedr
# 2039         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 2309         Lvl    AllPub    Inside       Gtl      Gilbert       RRAn
# 2323         Lvl    AllPub    Corner       Gtl      Gilbert       Norm
# 2338         Lvl    AllPub       FR2       Gtl      Somerst      Feedr
# 2347         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 2366         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 2590         HLS    AllPub    Inside       Gtl       Timber       Norm
# 2655         Lvl    AllPub    Corner       Gtl      NridgHt       Norm
# 2684         Lvl    AllPub   CulDSac       Gtl      Somerst       RRAn
# 2860         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 234        Norm     1Fam     2Story            6            5       2002
# 528        Norm     1Fam     1Story            6            3       1957
# 649        Norm     1Fam     2Story            7            6       2007
# 935        Norm     1Fam     1Story            7            5       2003
# 972        Norm     1Fam     1Story            7            5       2007
# 976        Norm   TwnhsE     1Story            7            5       2006
# 1242       Norm     1Fam     1Story           10            5       2006
# 1277       Norm     1Fam     2Story            8            5       2002
# 1689       Norm     1Fam     2Story            8            5       2002
# 1704       Norm     1Fam     1Story            7            5       2008
# 1880       Norm     1Fam     2Story            7            5       2002
# 1990       Norm     1Fam     2Story            7            5       2002
# 2002       Norm     1Fam     1Story            8            5       2006
# 2039       Norm     1Fam     2Story            7            5       2002
# 2309       Norm     1Fam     2Story            6            5       2007
# 2323       Norm     1Fam       SLvl            7            5       2003
# 2338       Norm     1Fam     1Story            7            5       2007
# 2347       Norm     1Fam     2Story            8            5       2007
# 2366       Norm   TwnhsE     1Story            8            5       2006
# 2590       Norm     1Fam     1Story            8            5       2006
# 2655       Norm     1Fam     2Story            8            5       2005
# 2684       Norm     1Fam     1Story            8            5       2006
# 2860       Norm     1Fam     1Story            6            5       2002
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 234           2002     Gable  CompShg     VinylSd     VinylSd       None
# 528           1975       Hip  CompShg     Wd Sdng       Stone       None
# 649           2007     Gable  CompShg     CemntBd     CmentBd       None
# 935           2003     Gable  CompShg     VinylSd     VinylSd       None
# 972           2008     Gable  CompShg     CemntBd     CmentBd       None
# 976           2007     Gable  CompShg     VinylSd     VinylSd       None
# 1242          2006     Gable  CompShg     VinylSd     VinylSd       None
# 1277          2002     Gable  CompShg     VinylSd     VinylSd       None
# 1689          2002     Gable  CompShg     VinylSd     VinylSd       None
# 1704          2009     Gable  CompShg     VinylSd     VinylSd       None
# 1880          2002     Gable  CompShg     VinylSd     VinylSd       None
# 1990          2002     Gable  CompShg     VinylSd     VinylSd       None
# 2002          2007       Hip  CompShg     VinylSd     VinylSd       None
# 2039          2002     Gable  CompShg     VinylSd     VinylSd       None
# 2309          2007     Gable  CompShg     VinylSd     VinylSd       None
# 2323          2003     Gable  CompShg     VinylSd     VinylSd       None
# 2338          2007     Gable  CompShg     VinylSd     VinylSd       None
# 2347          2007       Hip  CompShg     WdShing     Wd Shng       None
# 2366          2007     Gable  CompShg     VinylSd     VinylSd       None
# 2590          2007       Hip  CompShg     VinylSd     VinylSd       None
# 2655          2006     Gable  CompShg     CemntBd     CmentBd       None
# 2684          2006     Gable  CompShg     VinylSd     VinylSd       None
# 2860          2002     Gable  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 234          NaN        Gd        TA      PConc       Gd       TA
# 528          NaN        Gd        TA      PConc       TA       TA
# 649          NaN        Gd        TA      PConc       Gd       TA
# 935          NaN        Gd        TA      PConc       Gd       TA
# 972          NaN        Gd        TA      PConc       Gd       TA
# 976          NaN        Gd        TA      PConc       Gd       TA
# 1242         NaN        Ex        TA      PConc       Ex       Gd
# 1277         NaN        Gd        TA      PConc       Gd       TA
# 1689         NaN        Gd        TA      PConc       Ex       TA
# 1704         NaN        Gd        TA      PConc       Ex       TA
# 1880         NaN        Gd        TA      PConc       Gd       TA
# 1990         NaN        Gd        TA      PConc       Gd       TA
# 2002         NaN        Gd        TA      PConc       Ex       TA
# 2039         NaN        Gd        TA      PConc       Gd       TA
# 2309         NaN        Gd        TA     CBlock       Gd       TA
# 2323         NaN        Gd        TA      PConc       Gd       TA
# 2338         NaN        Gd        TA      PConc       Gd       TA
# 2347         NaN        Gd        TA      PConc       Ex       TA
# 2366         NaN        Gd        TA      PConc       Gd       TA
# 2590         NaN        Gd        TA      PConc       Gd       TA
# 2655         NaN        Gd        TA      PConc       Ex       TA
# 2684         NaN        Gd        TA      PConc       Ex       Gd
# 2860         NaN        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 234            No          GLQ       625.0          Unf         0.0
# 528            No          Rec      1219.0          Unf         0.0
# 649            No          Unf         0.0          Unf         0.0
# 935            No          GLQ       833.0          Unf         0.0
# 972            No          Unf         0.0          Unf         0.0
# 976            No          GLQ      1106.0          Unf         0.0
# 1242           Gd          GLQ      1386.0          Unf         0.0
# 1277           No          GLQ       804.0          Unf         0.0
# 1689           No          GLQ       651.0          Unf         0.0
# 1704           No          Unf         0.0          Unf         0.0
# 1880           No          Unf         0.0          Unf         0.0
# 1990           No          Unf         0.0          Unf         0.0
# 2002           No          GLQ       666.0          Unf         0.0
# 2039           No          Unf         0.0          Unf         0.0
# 2309           No          Unf         0.0          Unf         0.0
# 2323           No          Unf         0.0          Unf         0.0
# 2338           No          Unf         0.0          Unf         0.0
# 2347           Av          GLQ       745.0          Unf         0.0
# 2366           No          Unf         0.0          Unf         0.0
# 2590           Av          GLQ       583.0          Unf         0.0
# 2655           Av          Unf         0.0          Unf         0.0
# 2684           No          GLQ      1562.0          Unf         0.0
# 2860           Av          GLQ       475.0          ALQ       297.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 234       235.0        860.0    GasA        Ex          Y      SBrkr
# 528       816.0       2035.0    GasA        TA          Y      SBrkr
# 649       813.0        813.0    GasA        Ex          Y      SBrkr
# 935       343.0       1176.0    GasA        Ex          Y      SBrkr
# 972      1428.0       1428.0    GasA        Ex          Y      SBrkr
# 976       135.0       1241.0    GasA        Ex          Y      SBrkr
# 1242      690.0       2076.0    GasA        Ex          Y      SBrkr
# 1277      324.0       1128.0    GasA        Ex          Y      SBrkr
# 1689      219.0        870.0    GasA        Ex          Y      SBrkr
# 1704     1436.0       1436.0    GasA        Ex          Y      SBrkr
# 1880      840.0        840.0    GasA        Ex          Y      SBrkr
# 1990      707.0        707.0    GasA        Ex          Y      SBrkr
# 2002      794.0       1460.0    GasA        Ex          Y      SBrkr
# 2039      952.0        952.0    GasA        Ex          Y      SBrkr
# 2309      768.0        768.0    GasA        Ex          Y      SBrkr
# 2323      384.0        384.0    GasA        Ex          Y      SBrkr
# 2338     1528.0       1528.0    GasA        Ex          Y      SBrkr
# 2347      210.0        955.0    GasA        Ex          Y      SBrkr
# 2366     1550.0       1550.0    GasA        Ex          Y      SBrkr
# 2590      963.0       1546.0    GasA        Ex          Y      SBrkr
# 2655     1209.0       1209.0    GasA        Ex          Y      SBrkr
# 2684      108.0       1670.0    GasA        Ex          Y      SBrkr
# 2860      142.0        914.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 234        860      1100             0       1960           1.0           0.0
# 528       2515         0             0       2515           1.0           0.0
# 649        822       843             0       1665           0.0           0.0
# 935       1200         0             0       1200           1.0           0.0
# 972       1428         0             0       1428           0.0           0.0
# 976       1241         0             0       1241           1.0           0.0
# 1242      2076         0             0       2076           1.0           0.0
# 1277      1128       903             0       2031           1.0           0.0
# 1689       878      1126             0       2004           1.0           0.0
# 1704      1436         0             0       1436           0.0           0.0
# 1880       840       885             0       1725           0.0           0.0
# 1990       707       707             0       1414           0.0           0.0
# 2002      1460         0             0       1460           0.0           0.0
# 2039       952       860             0       1812           0.0           0.0
# 2309       768       728             0       1496           0.0           0.0
# 2323       754       640             0       1394           0.0           0.0
# 2338      1528         0             0       1528           0.0           0.0
# 2347       955       925             0       1880           1.0           0.0
# 2366      1550         0             0       1550           0.0           0.0
# 2590      1564         0             0       1564           0.0           0.0
# 2655      1209      1044             0       2253           0.0           0.0
# 2684      1670         0             0       1670           1.0           0.0
# 2860       914         0             0        914           1.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 234          2         1             4             1          Gd
# 528          3         0             4             2          TA
# 649          2         1             3             1          Gd
# 935          2         0             2             1          Gd
# 972          2         0             3             1          Gd
# 976          1         1             1             1          Gd
# 1242         2         1             2             1          Ex
# 1277         2         1             3             1          Gd
# 1689         2         1             4             1          Gd
# 1704         2         0             3             1          Gd
# 1880         2         1             3             1          Gd
# 1990         2         1             3             1          Gd
# 2002         2         0             3             1          Gd
# 2039         2         1             3             1          TA
# 2309         3         0             3             1          Gd
# 2323         2         1             3             1          Gd
# 2338         3         2             3             1          Gd
# 2347         2         1             3             1          Ex
# 2366         2         1             2             1          Gd
# 2590         2         0             2             1          Ex
# 2655         2         1             3             1          Ex
# 2684         2         1             2             1          Gd
# 2860         1         0             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 234              8        Typ           2          TA    BuiltIn       2002.0
# 528              9       Maj1           2          TA     Attchd       1975.0
# 649              7        Typ           0        None     Attchd       2007.0
# 935              5        Typ           0        None     Attchd       2003.0
# 972              6        Typ           0        None     Attchd       2007.0
# 976              4        Typ           0        None     Attchd       2007.0
# 1242             7        Typ           1          Gd     Attchd       2006.0
# 1277             7        Typ           1          Gd     Attchd       2002.0
# 1689             8        Typ           1          Gd    BuiltIn       2002.0
# 1704             6        Typ           0        None     Attchd       2008.0
# 1880             6        Typ           0        None     Attchd       2002.0
# 1990             6        Typ           1          Gd     Attchd       2002.0
# 2002             6        Typ           1          Gd     Attchd       2006.0
# 2039             7        Typ           1          TA     Attchd       2002.0
# 2309             7        Typ           0        None     Attchd       2007.0
# 2323             7        Typ           1          TA    BuiltIn       2003.0
# 2338             6        Typ           1          TA     Attchd       2007.0
# 2347             8        Typ           1          Gd     Attchd       2007.0
# 2366             5        Typ           0        None     Attchd       2007.0
# 2590             6        Typ           1          Gd     Attchd       2207.0
# 2655             8        Typ           1          Gd     Attchd       2005.0
# 2684             6        Typ           1          Gd     Attchd       2006.0
# 2860             4        Typ           0        None       None          NaN
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 234           Fin         2.0       440.0         TA         TA          Y
# 528           RFn         2.0       484.0         TA         TA          Y
# 649           RFn         2.0       562.0         TA         TA          Y
# 935           RFn         2.0       555.0         TA         TA          Y
# 972           Fin         2.0       480.0         TA         TA          Y
# 976           Fin         2.0       569.0         TA         TA          Y
# 1242          Fin         3.0       850.0         TA         TA          Y
# 1277          RFn         2.0       577.0         TA         TA          Y
# 1689          Fin         3.0       644.0         TA         TA          Y
# 1704          Fin         2.0       529.0         TA         TA          Y
# 1880          RFn         2.0       550.0         TA         TA          Y
# 1990          Fin         2.0       403.0         TA         TA          Y
# 2002          Fin         2.0       480.0         TA         TA          Y
# 2039          RFn         2.0       469.0         TA         TA          Y
# 2309          Unf         2.0       572.0         TA         TA          Y
# 2323          Fin         2.0       400.0         TA         TA          Y
# 2338          Unf         2.0       480.0         TA         TA          Y
# 2347          Fin         3.0       880.0         TA         TA          Y
# 2366          Fin         2.0       528.0         TA         TA          Y
# 2590          RFn         2.0       502.0         TA         TA          Y
# 2655          Fin         2.0       575.0         TA         TA          Y
# 2684          RFn         3.0       928.0         TA         TA          Y
# 2860         None         0.0         0.0       None       None          N
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 234          288           48              0          0            0
# 528            0            0            200          0            0
# 649            0            0              0          0            0
# 935            0           41              0          0            0
# 972            0          120              0          0            0
# 976            0          116              0          0            0
# 1242         216          229              0          0            0
# 1277           0          211              0          0            0
# 1689           0           48              0          0            0
# 1704           0          121              0          0            0
# 1880           0           48              0          0            0
# 1990         100           35              0          0            0
# 2002           0           20              0          0            0
# 2039         144          112              0          0            0
# 2309         100            0              0          0            0
# 2323         100            0              0          0            0
# 2338           0          228              0          0            0
# 2347         168          127              0          0            0
# 2366           0          102              0          0            0
# 2590         132            0              0          0            0
# 2655         243          142              0          0            0
# 2684           0          240            200          0            0
# 2860          32            0              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 234          0   None  None        None        0       5    2010       WD
# 528          0   None  None        None        0       3    2007       WD
# 649          0   None  None        None        0       5    2008       WD
# 935          0   None  None        None        0       8    2009       WD
# 972          0   None  None        None        0      12    2008      New
# 976          0   None  None        None        0      11    2007      New
# 1242         0   None  None        None        0       9    2006      New
# 1277         0   None  None        None        0       3    2008       WD
# 1689         0   None  None        None        0       7    2009       WD
# 1704         0   None  None        None        0      10    2009      New
# 1880         0   None  None        None        0      11    2009       WD
# 1990         0   None  None        None        0       4    2008       WD
# 2002         0   None  None        None        0       8    2008       WD
# 2039         0   None  None        None        0       4    2008       WD
# 2309         0   None  None        None        0       5    2007      New
# 2323         0   None  None        None        0      10    2007       WD
# 2338         0   None  None        None        0       9    2007      New
# 2347         0   None  None        None        0      12    2007      New
# 2366         0   None  None        None        0       7    2007      New
# 2590         0   None  None        None        0       9    2007      New
# 2655         0   None  None        None        0       7    2006      New
# 2684         0   None  None        None        0       9    2006      New
# 2860         0   None  None        None        0       4    2006       WD
#
#      SaleCondition
# 234         Normal
# 528         Alloca
# 649         Normal
# 935         Normal
# 972        Partial
# 976        Partial
# 1242       Partial
# 1277        Normal
# 1689        Normal
# 1704       Partial
# 1880        Normal
# 1990        Normal
# 2002        Normal
# 2039        Normal
# 2309       Partial
# 2323        Normal
# 2338       Partial
# 2347       Partial
# 2366       Partial
# 2590       Partial
# 2655       Partial
# 2684       Partial
# 2860        Normal

# %% [markdown]
# No incongruencies here either. The rest can be safely imputed with 0 since this means that the property is not present in the house.

# %%
numeric_dtypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerics = []
for i in features.columns:
    if features[i].dtype in numeric_dtypes:
        numerics.append(i)

features.update(features[numerics].fillna(0))

nulls = np.sum(features.isnull())
nullcols = nulls.loc[(nulls != 0)]
dtypes = features.dtypes
dtypes2 = dtypes.loc[(nulls != 0)]
info = pd.concat([nullcols, dtypes2], axis=1).sort_values(by=0, ascending=False)
print(info)
print("There are", len(nullcols), "columns with missing values")
# Out:
# Empty DataFrame
# Columns: [0, 1]
# Index: []
# There are 0 columns with missing values

# %% [markdown]
# # 3.3 Incorrect values
# Some values can be obviously wrong and this might impact our model. I used min and max values to check odd values in the data.

# %%
features.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  2917.000000  2917.000000    2917.000000  2917.000000  2917.000000
# mean     57.135756    69.436064   10139.439150     6.086390     5.564964
# std      42.532140    21.208242    7807.036512     1.406704     1.113414
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    60.000000    7476.000000     5.000000     5.000000
# 50%      50.000000    70.000000    9452.000000     6.000000     5.000000
# 75%      70.000000    80.000000   11556.000000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  2917.000000   2917.000000  2917.000000  2917.000000  2917.000000
# mean   1971.287967   1984.248200   100.931436   438.864930    49.599246
# std      30.286991     20.892257   178.032499   444.180542   169.232130
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000
# 25%    1953.000000   1965.000000     0.000000     0.000000     0.000000
# 50%    1973.000000   1993.000000     0.000000   368.000000     0.000000
# 75%    2001.000000   2004.000000   163.000000   733.000000     0.000000
# max    2010.000000   2010.000000  1600.000000  4010.000000  1526.000000
#
#         BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF  \
# count  2917.00000  2917.000000  2917.000000  2917.000000   2917.000000
# mean    560.50360  1048.967775  1157.692492   335.861502      4.697635
# std     439.69883   429.472008   385.264298   428.119663     46.412570
# min       0.00000     0.000000   334.000000     0.000000      0.000000
# 25%     220.00000   793.000000   876.000000     0.000000      0.000000
# 50%     467.00000   988.000000  1082.000000     0.000000      0.000000
# 75%     804.00000  1302.000000  1384.000000   704.000000      0.000000
# max    2336.00000  5095.000000  5095.000000  2065.000000   1064.000000
#
#          GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath     HalfBath  \
# count  2917.000000   2917.000000   2917.000000  2917.000000  2917.000000
# mean   1498.251628      0.428865      0.061364     1.567364     0.379842
# std     496.908626      0.523943      0.245687     0.552465     0.502782
# min     334.000000      0.000000      0.000000     0.000000     0.000000
# 25%    1126.000000      0.000000      0.000000     1.000000     0.000000
# 50%    1444.000000      0.000000      0.000000     2.000000     0.000000
# 75%    1743.000000      1.000000      0.000000     2.000000     1.000000
# max    5095.000000      3.000000      2.000000     4.000000     2.000000
#
#        BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  GarageYrBlt  \
# count   2917.000000   2917.000000   2917.000000  2917.000000  2917.000000
# mean       2.860130      1.044566      6.448063     0.596160  1871.627014
# std        0.822967      0.214532      1.564281     0.644773   447.158503
# min        0.000000      0.000000      2.000000     0.000000     0.000000
# 25%        2.000000      1.000000      5.000000     0.000000  1957.000000
# 50%        3.000000      1.000000      6.000000     1.000000  1977.000000
# 75%        3.000000      1.000000      7.000000     1.000000  2001.000000
# max        8.000000      3.000000     15.000000     4.000000  2207.000000
#
#         GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# count  2917.000000  2917.000000  2917.000000  2917.000000    2917.000000
# mean      1.766198   472.412067    93.629414    47.280082      23.114158
# std       0.761412   214.584120   126.532643    67.118965      64.263424
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%       1.000000   320.000000     0.000000     0.000000       0.000000
# 50%       2.000000   480.000000     0.000000    26.000000       0.000000
# 75%       2.000000   576.000000   168.000000    70.000000       0.000000
# max       5.000000  1488.000000  1424.000000   742.000000    1012.000000
#
#          3SsnPorch  ScreenPorch     PoolArea       MiscVal       MoSold  \
# count  2917.000000  2917.000000  2917.000000   2917.000000  2917.000000
# mean      2.604045    16.073363     2.088790     50.860816     6.213576
# std      25.196714    56.202054    34.561371    567.595198     2.713070
# min       0.000000     0.000000     0.000000      0.000000     1.000000
# 25%       0.000000     0.000000     0.000000      0.000000     4.000000
# 50%       0.000000     0.000000     0.000000      0.000000     6.000000
# 75%       0.000000     0.000000     0.000000      0.000000     8.000000
# max     508.000000   576.000000   800.000000  17000.000000    12.000000
#
#             YrSold
# count  2917.000000
# mean   2007.792938
# std       1.315328
# min    2006.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2010.000000

# %% [markdown]
# Looking at the min and max of each variable there are some errors in the data.
#
# GarageYrBlt - the max value is 2207, this is obviously wrong since the data is only until 2010.
# The rest of the data looks fine. Let's inspect this row a bit more carefully and impute an approximate correct value.

# %%
features[features['GarageYrBlt'] == 2207]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2590          20       RL         68.0     8298   Pave  None      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 2590         HLS    AllPub    Inside       Gtl       Timber       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 2590       Norm     1Fam     1Story            8            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 2590          2007       Hip  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 2590         0.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 2590           Av          GLQ       583.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 2590      963.0       1546.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 2590      1564         0             0       1564           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 2590         2         0             2             1          Ex
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 2590             6        Typ           1          Gd     Attchd       2207.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 2590          RFn         2.0       502.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 2590         132            0              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 2590         0   None  None        None        0       9    2007      New
#
#      SaleCondition
# 2590       Partial

# %% [markdown]
# This particular datapoint has YearBuilt in 2006 and YearRemodAdd in 2007. 2207 most likely is a data input error that should have been 2007 when the remodel happened. Let's impute 2007.

# %%
features.loc[2590, 'GarageYrBlt'] = 2007

# %% [markdown]
# # 3.4 Factorization
# There are features that are read in as numericals but are actually objects. Let's transform them.

# %%
factors = ['MSSubClass']
 


for i in factors:
    features.update(features[i].astype('str'))

# %% [markdown]
# # 3.5 Skew transformation features
# Let's check skew in our features and transform if necessary.

# %%
from scipy.stats import skew

numeric_dtypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerics2 = []
for i in features.columns:
    if features[i].dtype in numeric_dtypes:
        numerics2.append(i)

skew_features = features[numerics2].apply(lambda x: skew(x)).sort_values(ascending=False)
skews = pd.DataFrame({'skew': skew_features})
skews
# Out:
#                     skew
# MiscVal        21.939672
# PoolArea       17.688664
# LotArea        13.109495
# LowQualFinSF   12.084539
# 3SsnPorch      11.372080
# KitchenAbvGr    4.300550
# BsmtFinSF2      4.144503
# EnclosedPorch   4.002344
# ScreenPorch     3.945101
# BsmtHalfBath    3.929996
# MasVnrArea      2.621719
# OpenPorchSF     2.529358
# WoodDeckSF      1.844792
# 1stFlrSF        1.257286
# LotFrontage     1.103039
# GrLivArea       1.068750
# BsmtFinSF1      0.980645
# BsmtUnfSF       0.919688
# 2ndFlrSF        0.861556
# TotRmsAbvGrd    0.749232
# Fireplaces      0.725278
# HalfBath        0.696666
# TotalBsmtSF     0.671751
# BsmtFullBath    0.622415
# OverallCond     0.569314
# BedroomAbvGr    0.326568
# GarageArea      0.218753
# MoSold          0.197345
# OverallQual     0.189591
# FullBath        0.165514
# YrSold          0.131996
# GarageCars     -0.218309
# YearRemodAdd   -0.450134
# YearBuilt      -0.599194
# GarageYrBlt    -3.934463

# %% [markdown]
# I use the boxcox1p transformation here because I tried the log transform first but a lot of skew remained in the data. I use boxcox1p over normal boxcox because boxcox can't handle zero values.

# %%
from scipy.special import boxcox1p
from scipy.stats import boxcox_normmax

high_skew = skew_features[skew_features > 0.5]
skew_index = high_skew.index

for i in skew_index:
    features[i] = boxcox1p(features[i], boxcox_normmax(features[i]+1))

skew_features2 = features[numerics2].apply(lambda x: skew(x)).sort_values(ascending=False)
skews2 = pd.DataFrame({'skew': skew_features2})
skews2
# Out:
#                     skew
# PoolArea       15.595057
# 3SsnPorch       8.862045
# LowQualFinSF    8.492615
# MiscVal         5.237983
# BsmtHalfBath    3.779434
# KitchenAbvGr    3.778336
# ScreenPorch     3.152631
# BsmtFinSF2      2.578329
# EnclosedPorch   2.149133
# MasVnrArea      0.977618
# 2ndFlrSF        0.895453
# WoodDeckSF      0.785550
# HalfBath        0.732625
# OpenPorchSF     0.621231
# BsmtFullBath    0.616643
# Fireplaces      0.553135
# OverallCond     0.382457
# BsmtFinSF1      0.365986
# BedroomAbvGr    0.326568
# TotalBsmtSF     0.297009
# GarageArea      0.218753
# MoSold          0.197345
# OverallQual     0.189591
# FullBath        0.165514
# YrSold          0.131996
# LotFrontage     0.059189
# BsmtUnfSF       0.054195
# TotRmsAbvGrd    0.047190
# GrLivArea       0.008823
# 1stFlrSF       -0.007822
# LotArea        -0.138117
# GarageCars     -0.218309
# YearRemodAdd   -0.450134
# YearBuilt      -0.599194
# GarageYrBlt    -3.934463

# %% [markdown]
# # 3.6 Incomplete cases
# Checking to see if levels of my variables in my train and test set match and if not or if the level distribution is very low whether it should be deleted.

# %%
objects3 = []
for i in features.columns:
    if features[i].dtype == 'object':
        objects3.append(i)

# %%
print('Training set incomplete cases')
sums_features = features[objects3].apply(lambda x: len(np.unique(x)))
sums_features.sort_values(ascending=False)
# Out:
# Training set incomplete cases
# Neighborhood     25
# MSSubClass       16
# Exterior2nd      16
# Exterior1st      15
# Condition1        9
# SaleType          9
# Condition2        8
# HouseStyle        8
# RoofMatl          7
# GarageType        7
# Functional        7
# BsmtFinType1      7
# BsmtFinType2      7
# Heating           6
# RoofStyle         6
# BsmtQual          6
# SaleCondition     6
# Foundation        6
# FireplaceQu       6
# GarageCond        6
# GarageQual        6
# MSZoning          5
# LotConfig         5
# MiscFeature       5
# Fence             5
# BldgType          5
# HeatingQC         5
# BsmtExposure      5
# ExterCond         5
# Electrical        5
# BsmtCond          5
# GarageFinish      4
# LotShape          4
# ExterQual         4
# PoolQC            4
# KitchenQual       4
# MasVnrType        4
# LandContour       4
# Alley             3
# LandSlope         3
# Utilities         3
# PavedDrive        3
# Street            2
# CentralAir        2
# dtype: int64

# %% [markdown]
# Let's take a closer look at some of these lower numbered variables.

# %%
print(features['Street'].value_counts())
print('-----')
print(features['Utilities'].value_counts())
print('-----')
print(features['CentralAir'].value_counts())
print('-----')
print(features['PavedDrive'].value_counts())
# Out:
# Pave    2905
# Grvl      12
# Name: Street, dtype: int64
# -----
# AllPub    2914
# None         2
# NoSeWa       1
# Name: Utilities, dtype: int64
# -----
# Y    2721
# N     196
# Name: CentralAir, dtype: int64
# -----
# Y    2639
# N     216
# P      62
# Name: PavedDrive, dtype: int64

# %% [markdown]
# I experimented a bunch with this and decided in the end that if a column has low amount of levels and most values are in the same class (>97%) I'd remove them.
#
# Let's delete Utilities because of how unbalanced it is.

# %%
features = features.drop(['Utilities', 'Street'], axis=1)

# %% [markdown]
# # 3.7 Creating features
# In this section I create some features that can be created from the current data.
#
# Size of the house. There are a few variables dealing with square footage, I don't use TotalBsmtSF as a proxy for the basement because I believe unfinished square feet in the basement area won't have a big impact on price as it needs money to make it 'livable' square footage, so I just use BsmtSF1 and BsmtSF2.
#
# * BsmtFinSF1
# * BsmtFinSF2
# * 1stFlrSF
# * 2ndFlrSF
#
# Another combined variable is the bathrooms in the house. I count fullbath for 1 and halfbath for 0.5.
#
# * FullBath
# * HalfBath
# * BsmtFullBath
# * BsmtHalfBath
#
# Another combined variable is the total porch size.
#
# * OpenPorchSF
# * EnclosedPorch
# * 3SsnPorch
# * Screenporch
# * WoodDeckSF
#
# Next to that I make some simplified features.
#
# * haspool
# * has2ndfloor
# * hasgarage
# * hasbsmt
# * hasfireplace

# %%
features['Total_sqr_footage'] = features['BsmtFinSF1'] + features['BsmtFinSF2'] + features['1stFlrSF'] + features['2ndFlrSF']

features['Total_Bathrooms'] = features['FullBath'] + (0.5*features['HalfBath']) + features['BsmtFullBath'] + (0.5*features['BsmtHalfBath'])

features['Total_porch_sf'] = features['OpenPorchSF'] + features['3SsnPorch'] + features['EnclosedPorch'] + features['ScreenPorch'] + features['WoodDeckSF']

# simplified features
features['haspool'] = features['PoolArea'].apply(lambda x: 1 if x > 0 else 0)

features['has2ndfloor'] = features['2ndFlrSF'].apply(lambda x: 1 if x > 0 else 0)

features['hasgarage'] = features['GarageArea'].apply(lambda x: 1 if x > 0 else 0)

features['hasbsmt'] = features['TotalBsmtSF'].apply(lambda x: 1 if x > 0 else 0)

features['hasfireplace'] = features['Fireplaces'].apply(lambda x: 1 if x > 0 else 0)

# %% [markdown]
# # 3.8 Creating Dummies
# Since sklearn lm.fit() does not accept strings we have to convert our objects to dummy variables.

# %%
features.shape
# Out:
# (2917, 85)

# %%
final_features = pd.get_dummies(features).reset_index(drop=True)
final_features.shape
# Out:
# (2917, 321)

# %% [markdown]
# Now we resplit the model in test and train

# %%
y.shape
# Out:
# (1458,)

# %%
X = final_features.iloc[:len(y),:]
testing_features = final_features.iloc[len(y):,:]

print(X.shape)
print(testing_features.shape)
# Out:
# (1458, 321)
# (1459, 321)

# %% [markdown]
# # Overfitting prevention
# Outliers
#
# Let's do a little bit more in-depth and rigorous analysis first on outliers. I'll employ Leave-One-Out methodology with OLS to find which points have a significant effect on our model fit.

# %%
import statsmodels.api as sm

ols = sm.OLS(endog = y, exog = X)
fit = ols.fit()
test2 = fit.outlier_test()['bonf(p)']
# Out:
# C:\Users\Martin\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# C:\Users\Martin\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:309: RuntimeWarning: invalid value encountered in sqrt
#   return  self.results.resid / sigma / np.sqrt(1 - hii)
# C:\Users\Martin\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\Martin\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\Martin\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Users\Martin\Anaconda3\lib\site-packages\statsmodels\stats\multitest.py:147: RuntimeWarning: invalid value encountered in less_equal
#   reject = pvals <= alphacBonf
# C:\Users\Martin\Anaconda3\lib\site-packages\statsmodels\stats\multitest.py:251: RuntimeWarning: invalid value encountered in greater
#   pvals_corrected[pvals_corrected>1] = 1

# %%
outliers = list(test2[test2<1e-3].index)
outliers
# Out:
# [30, 88, 462, 631, 1322]

# %% [markdown]
# So we find that these are outliers. Let's delete these.

# %%
X = X.drop(X.index[outliers])
y = y.drop(y.index[outliers])

# %% [markdown]
# # Dummy levels
# To prevent overfitting I'll also remove columns that have more than 97% 1 or 0 after doing pd.get_dummies.

# %%
overfit = []
for i in X.columns:
    counts = X[i].value_counts()
    zeros = counts.iloc[0]
    if zeros / len(X) * 100 > 99.94:
        overfit.append(i)

# %%
overfit
# Out:
# ['MSSubClass_150', 'BsmtQual_Po']

# %% [markdown]
# Let's drop these from 'X' and 'testing_features'. Let's also drop MSZoning_C (all). It has about 99.44% zeros but unlike others with that kind of percentage it's being included in my lasso/ridge/elasticnet models with quite strong coefficient sizes.

# %%
overfit.append('MSZoning_C (all)')

# %%
X.drop(overfit, axis=1, inplace=True)
testing_features.drop(overfit, axis=1, inplace=True)
# Out:
# C:\Users\Martin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print(X.shape)
print(testing_features.shape)
# Out:
# (1453, 318)
# (1459, 318)

# %% [markdown]
# # 4.0 Baseline model
# Full Model w/ kfold cross validation
# Let's build a baseline linear regression model to benchmark our feature selected models and advanced models on.
#
# I decided not to do a manual train/test split but instead rely completely on 10-fold cross-validation for every model including our benchmark.
#
# Our in-class benchmark has an RMSE of ~0.14 which is the goal to beat but I will rebuild a benchmark model in this notebook too.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import make_pipeline

# Build our model method

lm = LinearRegression()

kfolds = KFold(n_splits=10, shuffle=True, random_state=23)

# build our model scoring function
def cv_rmse(model):
    rmse = np.sqrt(-cross_val_score(model, X, y, scoring='neg_mean_squared_error',
                                   cv = kfolds, n_jobs=-1))
    return rmse

# second scoring metric
def cv_rmsle(model):
    rmsle = np.sqrt(np.log(-cross_val_score(model, X, y, scoring = 'neg_mean_squared_error',
                                           cv = kfolds, n_jobs=-1)))
    return rmsle

# %% [markdown]
# Let's fit our first model

# %%
benchmark_model = make_pipeline(RobustScaler(),
                               lm).fit(X=X, y=y)
cv_rmse(benchmark_model).mean()
# Out:
# 83431827.34660305

# %% [markdown]
# # Visualizing baseline model
# Let's see how the residuals and predictions vs actual values are distributed. Here I should note this looks absolutely ridiculous for a reason I can't figure out yet. Basically, for some reason, my baseline model gives an incredibly high residual error. I believe this is due to the fact that the dimensionality of my model is crazy high compared to the amount of data (~1500 rows vs ~320 columns). This gets reduced down with feature selection but the baseline model includes all which leads to a ton of multicollinearity causing high RMSE values.

# %% [markdown]
# # Feature Selection

# %% [markdown]
# Before starting this section it should be noted that I will try to be extra careful not to create contamination during feature selection. Meaning that I will select features constrained per fold in my cross-validation to ensure no data leakage happens.
#
# Filter methods
#
# Coefficient importance

# %%
coeffs = pd.DataFrame(list(zip(X.columns, benchmark_model.steps[1][1].coef_)), columns = ['Predictors','Coefficients'])
coeffs.sort_values(by='Coefficients', ascending=False)
# Out:
#              Predictors  Coefficients
# 35    Total_sqr_footage  1.341580e+10
# 37       Total_porch_sf  2.196705e+09
# 67         LotShape_IR3  1.652724e+09
# 66         LotShape_IR2  1.652724e+09
# 68         LotShape_Reg  1.652724e+09
# 65         LotShape_IR1  1.652724e+09
# 184        ExterQual_Ex  8.779051e+08
# 187        ExterQual_TA  8.779051e+08
# 186        ExterQual_Gd  8.779051e+08
# 185        ExterQual_Fa  8.779051e+08
# 40            hasgarage  8.224498e+08
# 129   HouseStyle_1.5Unf  7.744718e+08
# 132   HouseStyle_2.5Unf  7.744718e+08
# 131   HouseStyle_2.5Fin  7.744718e+08
# 128   HouseStyle_1.5Fin  7.744718e+08
# 133   HouseStyle_2Story  7.744718e+08
# 135     HouseStyle_SLvl  7.744718e+08
# 130   HouseStyle_1Story  7.744718e+08
# 134   HouseStyle_SFoyer  7.744718e+08
# 42         hasfireplace  7.632307e+08
# 74    LotConfig_CulDSac  7.169306e+08
# 73     LotConfig_Corner  7.169306e+08
# 77     LotConfig_Inside  7.169306e+08
# 75        LotConfig_FR2  7.169306e+08
# 76        LotConfig_FR3  7.169306e+08
# 36      Total_Bathrooms  6.933028e+08
# 141      RoofStyle_Shed  6.315564e+08
# 140   RoofStyle_Mansard  6.315564e+08
# 138   RoofStyle_Gambrel  6.315564e+08
# 139       RoofStyle_Hip  6.315564e+08
# ..                  ...           ...
# 283     GarageCond_None -4.350708e+08
# 269     GarageType_None -4.350708e+08
# 16         BsmtHalfBath -5.378173e+08
# 271   GarageFinish_None -5.388160e+08
# 18             HalfBath -5.748388e+08
# 27          OpenPorchSF -7.054512e+08
# 57        MSSubClass_90 -7.518901e+08
# 123       BldgType_1Fam -8.319498e+08
# 127     BldgType_TwnhsE -8.319498e+08
# 126      BldgType_Twnhs -8.319498e+08
# 124     BldgType_2fmCon -8.319498e+08
# 183    MasVnrType_Stone -1.006140e+09
# 181  MasVnrType_BrkFace -1.006140e+09
# 182     MasVnrType_None -1.006140e+09
# 180   MasVnrType_BrkCmn -1.006140e+09
# 15         BsmtFullBath -1.068578e+09
# 17             FullBath -1.075635e+09
# 41              hasbsmt -1.247682e+09
# 197    Foundation_Stone -1.386359e+09
# 195    Foundation_PConc -1.386359e+09
# 194   Foundation_CBlock -1.386359e+09
# 196     Foundation_Slab -1.386359e+09
# 193   Foundation_BrkTil -1.386359e+09
# 198     Foundation_Wood -1.386359e+09
# 26           WoodDeckSF -2.136129e+09
# 7            BsmtFinSF1 -2.348792e+09
# 270    GarageFinish_Fin -2.478017e+09
# 272    GarageFinish_RFn -2.478017e+09
# 273    GarageFinish_Unf -2.478017e+09
# 12             2ndFlrSF -1.409295e+10
#
# [318 rows x 2 columns]

# %% [markdown]
# # 4.1 Embedded methods
#
# Ridge Regression (L2 penalty)

# %%
from sklearn.linear_model import RidgeCV

def ridge_selector(k):
    ridge_model = make_pipeline(RobustScaler(),
                               RidgeCV(alphas = [k],
                                      cv=kfolds)).fit(X,y)
    ridge_rmse = cv_rmse(ridge_model).mean()
    return ridge_rmse

# %%
r_alphas = [0.0001, 0.0003, 0.0005, 0.0007, 0.0009, 0.01,
           0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 20, 30, 50, 60, 70, 80]

ridge_scores = []
for alpha in r_alphas:
    score = ridge_selector(alpha)
    ridge_scores.append(score)

# %%
plt.plot(r_alphas, ridge_scores, label='Ridge')
plt.legend('center')
plt.xlabel('alpha')
plt.ylabel('score')

ridge_score_table = pd.DataFrame({'RMSE' : ridge_scores}, r_alphas)
ridge_score_table
# Out:
#              RMSE
# 0.0001   0.113943
# 0.0003   0.112867
# 0.0005   0.112278
# 0.0007   0.111890
# 0.0009   0.111619
# 0.0100   0.110398
# 0.0500   0.109388
# 0.1000   0.108505
# 0.3000   0.106651
# 1.0000   0.104760
# 3.0000   0.103561
# 5.0000   0.103119
# 10.0000  0.102690
# 15.0000  0.102614
# 20.0000  0.102685
# 30.0000  0.103024
# 50.0000  0.103982
# 60.0000  0.104506
# 70.0000  0.105038
# 80.0000  0.105571

# %%
alphas_alt = [14.5, 14.6, 14.7, 14.8, 14.9, 15, 15.1, 15.2, 15.3, 15.4, 15.5]

ridge_model2 = make_pipeline(RobustScaler(),
                            RidgeCV(alphas = alphas_alt,
                                   cv=kfolds)).fit(X,y)

cv_rmse(ridge_model2).mean()
# Out:
# 0.10263463637867336

# %%
ridge_model2.steps[1][1].alpha_
# Out:
# 14.6

# %% [markdown]
# # 4.2 Lasso Regression (L1 penanlty)

# %%
from sklearn.linear_model import LassoCV

alphas = [0.00005, 0.0001, 0.0003, 0.0005, 0.0007, 0.0009, 0.01]

alphas2 = [0.00005, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008]

lasso_model2 = make_pipeline(RobustScaler(),
                            LassoCV(max_iter=1e7,
                                   alphas=alphas2, random_state=42)).fit(X,y)

# %%
scores = lasso_model2.steps[1][1].mse_path_

plt.plot(alphas2, scores, label='Lasso')
plt.legend(loc='center')
plt.xlabel('alpha')
plt.ylabel('RMSE')
plt.tight_layout()
plt.show()

# %%
scores
# Out:
# array([[0.00963785, 0.01416008, 0.00997862],
#        [0.00961535, 0.01414688, 0.00995153],
#        [0.0096436 , 0.01413774, 0.00994494],
#        [0.00968033, 0.01415589, 0.00996418],
#        [0.00969574, 0.01416629, 0.01003473],
#        [0.00956391, 0.01416394, 0.01009973],
#        [0.00966714, 0.01434794, 0.01029942],
#        [0.01031401, 0.01415747, 0.01082141],
#        [0.01134332, 0.01446684, 0.0114176 ]])

# %%
lasso_model2.steps[1][1].alpha_
# Out:
# 0.0007

# %%
cv_rmse(lasso_model2).mean()
# Out:
# 0.10299719809830576

# %%
coeffs = pd.DataFrame(list(zip(X.columns, lasso_model2.steps[1][1].coef_)), columns = ['Predictors', 'Coefficients'])

# %%
used_coeffs = coeffs[coeffs['Coefficients']!=0].sort_values('Coefficients', ascending=False)
print(used_coeffs.shape)
print(used_coeffs)
# Out:
# (92, 2)
#                 Predictors  Coefficients
# 2              OverallQual      0.112749
# 35       Total_sqr_footage      0.100129
# 4                YearBuilt      0.096562
# 87    Neighborhood_Crawfor      0.086172
# 14               GrLivArea      0.080195
# 11                1stFlrSF      0.077902
# 152    Exterior1st_BrkFace      0.070110
# 10             TotalBsmtSF      0.066959
# 256         Functional_Typ      0.061497
# 103   Neighborhood_StoneBr      0.061188
# 102   Neighborhood_Somerst      0.057608
# 246         KitchenQual_Ex      0.052983
# 199            BsmtQual_Ex      0.049353
# 309           SaleType_New      0.046735
# 3              OverallCond      0.044895
# 210        BsmtExposure_Gd      0.038525
# 108        Condition1_Norm      0.038279
# 84    Neighborhood_BrkSide      0.035301
# 60             MSZoning_RL      0.034477
# 1                  LotArea      0.032123
# 195       Foundation_PConc      0.025664
# 5             YearRemodAdd      0.025349
# 97    Neighborhood_NridgHt      0.024946
# 24              GarageCars      0.022179
# 53           MSSubClass_70      0.022068
# 234           HeatingQC_Ex      0.021587
# 64              Alley_Pave      0.020808
# 37          Total_porch_sf      0.020777
# 22              Fireplaces      0.017291
# 123          BldgType_1Fam      0.016895
# ..                     ...           ...
# 249         KitchenQual_TA     -0.001384
# 8               BsmtFinSF2     -0.001390
# 174    Exterior2nd_Plywood     -0.001673
# 33                  MoSold     -0.001719
# 275          GarageQual_Fa     -0.002829
# 155    Exterior1st_HdBoard     -0.003098
# 95     Neighborhood_NWAmes     -0.003443
# 32                 MiscVal     -0.003544
# 187           ExterQual_TA     -0.004098
# 34                  YrSold     -0.004445
# 238           HeatingQC_TA     -0.004477
# 190           ExterCond_Gd     -0.005465
# 260       FireplaceQu_None     -0.006442
# 19            BedroomAbvGr     -0.006611
# 212        BsmtExposure_No     -0.007533
# 162    Exterior1st_Wd Sdng     -0.007902
# 311            SaleType_WD     -0.008092
# 20            KitchenAbvGr     -0.008095
# 106      Condition1_Artery     -0.010642
# 98    Neighborhood_OldTown     -0.011200
# 204            BsmtCond_Fa     -0.012691
# 220       BsmtFinType1_Unf     -0.013652
# 88    Neighborhood_Edwards     -0.019898
# 57           MSSubClass_90     -0.020717
# 92    Neighborhood_Mitchel     -0.020929
# 9                BsmtUnfSF     -0.021185
# 48           MSSubClass_30     -0.022090
# 90     Neighborhood_IDOTRR     -0.022675
# 239           CentralAir_N     -0.041062
# 312  SaleCondition_Abnorml     -0.069078
#
# [92 rows x 2 columns]

# %%
used_coeffs_values = X[used_coeffs['Predictors']]
used_coeffs_values.shape
# Out:
# (1453, 92)

# %%
overfit_test2 = []
for i in used_coeffs_values.columns:
    counts2 = used_coeffs_values[i].value_counts()
    zeros2 = counts2.iloc[0]
    if zeros2 / len(used_coeffs_values) * 100 > 99.5:
        overfit_test2.append(i)
        
overfit_test2
# Out:
# ['PoolArea']

# %% [markdown]
# # 4.3 Elastic Net (L1 and L2 penalty)
# One of the issues with Lasso is that it's likely to pick, from correlated features, one at random. Elastic net would pick both. Its a bit of a mix between ridge and lasso. I decided to include it since R's implementation of ridge regression actually invovles some elasticNet properties.

# %%
from sklearn.linear_model import ElasticNetCV

e_alphas = [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007]
e_l1ratio = [0.8, 0.85, 0.9, 0.95, 0.99, 1]

elastic_cv = make_pipeline(RobustScaler(),
                          ElasticNetCV(max_iter=1e7, alphas=e_alphas,
                                      cv=kfolds, l1_ratio=e_l1ratio))
elastic_model3 = elastic_cv.fit(X,y)

# %%
cv_rmse(elastic_model3).mean()
# Out:
# 0.1026801104818051

# %%
print(elastic_model3.steps[1][1].l1_ratio_)
print(elastic_model3.steps[1][1].alpha_)
# Out:
# 0.9
# 0.0002

# %% [markdown]
# # 4.4 Xgboost
# The project I made this notebook for we weren't allowed to use more advanced algorithms than lasso, ridge, elasticnet. This was added later to see if I could improve my score.

# %%
from sklearn.model_selection import GridSearchCV
from matplotlib.pyplot import rcParams
rcParams['figure.figsize']= 12,4
# %matplotlib inline
import xgboost as xgb
from xgboost import XGBRegressor

# %% [markdown]
# Belows function was used to obtain the optimal boosting rounds. This is accomplished useing xgb.cv's early stopping.

# %%
from sklearn.metrics import mean_squared_error

def modelfit(alg, dtrain, target, useTrainCV=True, 
             cv_folds=5, early_stopping_rounds=50):
    
    if useTrainCV:
        xgb_param = alg.get_xgb_params()
        xgtrain = xgb.DMatrix(dtrain.values, 
                              label=y.values)
        
        print("\nGetting Cross-validation result..")
        cvresult = xgb.cv(xgb_param, xgtrain, 
                          num_boost_round=alg.get_params()['n_estimators'], 
                          nfold=cv_folds,metrics='rmse', 
                          early_stopping_rounds=early_stopping_rounds,
                          verbose_eval = True)
        alg.set_params(n_estimators=cvresult.shape[0])
    
    #Fit the algorithm on the data
    print("\nFitting algorithm to data...")
    alg.fit(dtrain, target, eval_metric='rmse')
        
    #Predict training set:
    print("\nPredicting from training data...")
    dtrain_predictions = alg.predict(dtrain)
        
    #Print model report:
    print("\nModel Report")
    print("RMSE : %.4g" % np.sqrt(mean_squared_error(target.values,
                                             dtrain_predictions)))

# %% [markdown]
# Gridsearching gave me optimal parameters for XGBoost

# %%
xgb3 = XGBRegressor(learning_rate=0.01, n_estimators=3460, max_depth=3,
                   min_child_weight=0, gamma=0, subsample=0.7,
                   colsample_bytree=0.7, objective='reg:linear',
                   ntread=4, scale_pos_weight=1, seed=27,
                   reg_alpha=0.00006)
xgb_fit = xgb3.fit(X,y)

# %% [markdown]
# # 4.5 Support Vector Regression
#
# Gridsearching gave me optimal C and gamma for SVR

# %%
from sklearn import svm
svr_opt = svm.SVR(C = 100000, gamma = 1e-08)

svr_fit = svr_opt.fit(X, y)

# %% [markdown]
# # 4.6 LightGBM

# %%
from lightgbm import LGBMRegressor

lgbm_model = LGBMRegressor(objective='regression', num_leaves=5,
                          learning_rate=0.05, n_estimators=720,
                          max_bin = 55, bagging_fraction = 0.8,
                          bagging_freq = 5, feature_fraction = 0.2319,
                          feature_fraction_seed=9, bagging_seed=9,
                          min_data_in_leaf=6, min_sum_hessian_in_leaf=11)

# %%
cv_rmse(lgbm_model).mean()
# Out:
# 0.10693397909635234

# %%
lgbm_fit = lgbm_model.fit(X,y)

# %% [markdown]
# # 4.7 Ensemble methods
#
# Let's see if I can get a better performance on the test data by employing ensemble methods. To stay in the constraints of the exercise I won't employ stronger models but instead combine three models.
#
# * LassoCV
# * RidgeCV
# * Elasticnet
#
# Experimenting with averaging cost a lot of time since local RMSE and kaggle RMSLE are disconnected at this point. Basically I am optimizing the tradeoff between under and over fitting.
#
# First I'll build a meta-regressor through a process called stacking generalizations which trains a model on a part of the training set (it gets split first into a new training set and a holdout set). Then the algorithm test these models on the holdout set and uses these predictions (called out-of-fold predictions) as input for the 'meta model'. Below is a grahpical representation of the process.

# %% [markdown]
# # Ensemble 1 - Stacking GeneralizationEnsemble 1 - Stacking Generalization
#
# To try to eek out more performance of our already decent rank let's try Stacking Generalization, I tried a few different options. Vecstack package from python seemed to be implementing it incorrectly, so instead I decided to use the mlxtend package.To try to eek out more performance of our already decent rank let's try Stacking Generalization, I tried a few different options. Vecstack package from python seemed to be implementing it incorrectly, so instead I decided to use the mlxtend package.

# %%
from mlxtend.regressor import StackingCVRegressor
from sklearn.pipeline import make_pipeline

ridge = make_pipeline(RobustScaler(),
                     RidgeCV(alphas = alphas_alt, cv=kfolds))
lasso = make_pipeline(RobustScaler(),
                     LassoCV(max_iter=1e7, alphas=alphas2,
                            random_state=42, cv=kfolds, n_jobs=-1))
elasticnet = make_pipeline(RobustScaler(),
                          ElasticNetCV(max_iter=1e7, alphas=e_alphas,
                                      cv=kfolds, l1_ratio=e_l1ratio, n_jobs=-1))
lightgbm = make_pipeline(RobustScaler(),
                        LGBMRegressor(objective='regression', num_leaves=5,
                                    learning_rate=0.05, n_estimators=720,
                                    max_bin=55, baging_farction=0.8,
                                    bagging_freq=5, feature_fraction=0.2319,
                                    feature_fraction_seed=9, bagging_seed=9,
                                    min_data_in_leaf=6, min_sum_hessian_in_leaf=11,
                                     ntread=4))
xgboost = make_pipeline(RobustScaler(),
                       XGBRegressor(learning_rate=0.01, n_estimators=3460,
                                   max_depth=3, min_child_weight=0, gamma=0,
                                   subsample=0.7, colsample_bytree=0.7,
                                   objective='reg:linear', ntread=4,
                                   scale_pos_weight=1,seed=27, reg_alpha=0.00006))

# stack
stack_gen = StackingCVRegressor(regressors=(ridge, lasso, elasticnet, xgboost, lightgbm),
                               meta_regressor=xgboost, use_features_in_secondary=True)


stackX = np.array(X)
stacky = np.array(y)

# %%
print('cross validated scores')

for model, label in zip([ridge, lasso, elasticnet, xgboost, lightgbm, stack_gen],
                       ['RidgeCV', 'LassoCV', 'ElasticNetCV', 'xgboost', 
                       'lightgbm', 'StackingCVRegressor']):
    SG_scores = cross_val_score(model, stackX, stacky, cv=kfolds, scoring='neg_mean_squared_error', n_jobs=-1)
    print('RMSE', np.sqrt(-SG_scores.mean()), 'SD', SG_scores.std(), label)
# Out:
# cross validated scores
# RMSE 0.10337176442813514 SD 0.001993689509641551 RidgeCV
# RMSE 0.10330609893069818 SD 0.001993689509641551 LassoCV
# RMSE 0.1033996038463789 SD 0.001993689509641551 ElasticNetCV
# RMSE 0.10749085366866876 SD 0.001993689509641551 xgboost
# RMSE 0.10888879931745259 SD 0.001993689509641551 lightgbm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-698602630402> in <module>
#       4                        ['RidgeCV', 'LassoCV', 'ElasticNetCV', 'xgboost',
#       5                        'lightgbm', 'StackingCVRegressor']):
# ----> 6     SG_scores = cross_val_score(model, stackX, stacky, cv=kfolds, scoring='neg_mean_squared_error', n_jobs=-1)
#       7     print('RMSE', np.sqrt(-SG_scores.mean()), 'SD', scores.std(), label)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     340                                 n_jobs=n_jobs, verbose=verbose,
#     341                                 fit_params=fit_params,
# --> 342                                 pre_dispatch=pre_dispatch)
#     343     return cv_results['test_score']
#     344
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score)
#     204             fit_params, return_train_score=return_train_score,
#     205             return_times=True)
# --> 206         for train, test in cv.split(X, y, groups))
#     207
#     208     if return_train_score:
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# ~\Anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~\Anaconda3\lib\multiprocessing\pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
stack_gen_model = stack_gen.fit(stackX, stacky)

# %% [markdown]
# # Ensemble 2 - averaging
#
# Final averaging weights are mostly trial and error as at this point my local scores were so completely detached from my real kaggle score. In the end I felt that SVR wasn't helping my score so it's not included in my final predictions.

# %%
em_preds = elastic_model3.predict(testing_features)
lasso_preds = lasso_model2.predict(testing_features)
ridge_preds = ridge_model2.predict(testing_features)
stack_gen_preds = stack_gen_model.predict(testing_features)
xgb_preds = xgb_fit.predict(testing_features)
svr_preds = svr_fit.predict(testing_features)
lgbm_preds = lgbm_fit.predict(testing_features)

# %%
stack_preds = ((0.2*em_preds) + (0.1*lasso_preds) + (0.1*ridge_preds) + 
               (0.2*xgb_preds) + (0.1*lgbm_preds) + (0.3*stack_gen_preds))

# %% [markdown]
# # Actual Predictions
# I transform the predictions back to normal values because the model is trained with logSalePrice.

# %%
submission = pd.read_csv("sample_submission.csv")
submission.iloc[:,1] = np.expm1(stack_preds)
submission.to_csv("final_submission.csv", index=False)
